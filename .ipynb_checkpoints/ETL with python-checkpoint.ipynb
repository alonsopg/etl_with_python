html.txt AEG_Electrolux_L_72950__Opinion_1860264.html.txt AEG_Electrolux_L_74950_M__Opinion_1621410.html.txt AEG_Electrolux_L_74950_M__Opinion_1781454.html.txt AEG_Electrolux_L_74950_M__Opinion_1855361.html.txt AEG_Electrolux_L_74950_M__Opinion_1860252.html.txt AEG_Electrolux_L_74950_M__Opinion_1860288.html.txt AEG_Electrolux_L_74950_M__Opinion_1860306.html.txt AEG_Electrolux_L_74950_M__Opinion_1987186.html.txt AEG_Electrolux_L_74950_M__Opinion_2035893.html.txt AEG_Electrolux_L_75280_FL__Opinion_1966279.html.txt AEG_Electrolux_L_75280_FL__Opinion_2022526.html.txt AEG_Electrolux_L_75280_FL__Opinion_2028746.html.txt AEG_Electrolux_L_75280_FL__Opinion_2029866.html.txt AEG_Electrolux_L_75280_FL__Opinion_2090646.html.txt AEG_Electrolux_L_75280_FL__Opinion_2093157.html.txt AEG_Electrolux_L_75280_FL__Opinion_2095493.html.txt AEG_Electrolux_L_75280_FL__Opinion_2096227.html.txt AEG_Electrolux_L_75280_FL__Opinion_2099968.html.txt AEG_Electrolux_L_75280_FL__Opinion_2101605.html.txt AEG_Electrolux_L_75280_FL__Opinion_2103966.html.txt AEG_Electrolux_L_75280_F ...

# %%
# Open the file for reading.
with open('/Users/user/jupyter_notebooks/python_ETL/OpinionsTAG_txt_utf-8/AEG_Electrolux_L_75280_FL__Opinion_2093157.html.txt', 'r') as infile:
    data = infile.readlines()  # Read the contents of the file into memory.

# Return a list of the lines, breaking at line boundaries.
print(data)
# Out:
# ['La el DA0FS0 0.972269\n', 'mayoría mayoría NCFS000 1\n', 'de de SPS00 0.999984\n', 'las el DA0FP0 0.970954\n', 'lavadoras lavadora NCFP000 0.411969\n', 'tienen tener VMIP3P0 1\n', 'una uno DI0FS0 0.951575\n', 'carga carga NCFS000 0.952569\n', 'de de SPS00 0.999984\n', '5 5 Z 1\n', '- - Fg 1\n', '6 6 Z 1\n', 'kilos kilo NCMP000 1\n', ', , Fc 1\n', 'esta este PD0FS000 0.0132212\n', 'ofrece ofrecer VMIP3S0 0.97619\n', 'hasta hasta SPS00 0.957698\n', '8 8 Z 1\n', '- - Fg 1\n', '9 9 Z 1\n', 'kilos kilo NCMP000 1\n', 'con con SPS00 1\n', 'lo el DA0NS0 0.457533\n', 'que que PR0CN000 0.562517\n', 'es ser VSIP3S0 1\n', 'ideal ideal AQ0CS0 0.5\n', 'para para SPS00 0.999103\n', 'familias familia NCFP000 1\n', 'numerosas numeroso AQ0FP0 1\n', 'o o CC 0.999769\n', 'pequeños pequeño AQ0MP0 0.991071\n', 'negocios negocio NCMP000 1\n', 'tipo tipo NCMS000 1\n', 'barberías barbería NCFP000 1\n', ', , Fc 1\n', 'centros centro NCMP000 1\n', 'de de SPS00 0.999984\n', 'estética estética NCFS000 0.64273\n', ', , Fc 1\n', 'etc. etcétera Fs 1\n', 'Destaco destacar VMIP1S0 1\n', 'también también RG 1\n', 'que que CS 0.437483\n', 'tiene tener VMIP3S0 1\n', '1200 1200 Z 1\n', 'rpm r.p.m. NCFN000 1\n', 'por por SPS00 1\n', 'lo el DA0NS0 0.457533\n', 'que que PR0CN000 0.562517\n', 'la el DA0FS0 0.972269\n', 'ropa ropa NCFS000 1\n', 'sale salir VMIP3S0 0.814516\n', 'bastante bastante RG 0.776824\n', 'escurrida escurrir VMP00SF 1\n', '( ( Fpa 1\n', 'punto punto NCMS000 1\n', 'muy muy RG 1\n', 'positivo positivo AQ0MS0 0.58227\n', ') ) Fpt 1\n', 'y y CC 0.999962\n', 'eso ese PD0NS000 1\n', 'minimiza minimizar VMIP3S0 0.994868\n', 'el el DA0MS0 1\n', 'tiempo tiempo NCMS000 1\n', 'de de SPS00 0.999984\n', 'secado secado NCMS000 0.608058\n', 'en en SPS00 1\n', 'tendedero tendedero NCMS000 1\n', '( ( Fpa 1\n', 'si si CS 0.99954\n', 'no no RN 0.998134\n', 'se se P00CN000 0.465639\n', 'dispone disponer VMIP3S0 1\n', 'de de SPS00 0.999984\n', 'secadora secadora NCFS000 0.414738\n', ') ) Fpt 1\n', 'y y CC 0.999962\n', 'en en SPS00 1\n', 'una uno DI0FS0 0.951575\n', 'sociedad sociedad NCFS000 1\n', 'como como CS 0.999289\n', 'la el DA0FS0 0.972269\n', 'nuestra nuestro PX1FS0P0 0.0995146\n', 'todo todo DI0MS0 0.560961\n', 'el el DA0MS0 1\n', 'tiempo tiempo NCMS000 1\n', 'es ser VSIP3S0 1\n', 'oro oro NCMS000 0.923506\n', '. . Fp 1\n', '\n', 'Su su DP3CS0 1\n', 'sistema sistema NCMS000 1\n', 'mecánico mecánico AQ0MS0 0.65727\n', 'es ser VSIP3S0 1\n', 'inverter inverter VMN0000 1\n', ', , Fc 1\n', 'dispone disponer VMIP3S0 1\n', 'de de SPS00 0.999984\n', 'Display display NP00000 1\n', 'con con SPS00 1\n', 'pantalla pantalla NCFS000 1\n', 'de de SPS00 0.999984\n', 'LCD lcd NP00000 1\n', ', , Fc 1\n', 'sistema sistema NCMS000 1\n', 'anti-vibratorio anti-vibratorio NCMS000 0.916455\n', 'para para SPS00 0.999103\n', 'el el DA0MS0 1\n', 'tambor tambor NCMS000 1\n', 'UKS_II uks_ii NP00000 1\n', ', , Fc 1\n', 'el el DA0MS0 1\n', 'tambor tambor NCMS000 1\n', 'está estar VAIP3S0 0.999201\n', 'iluminado iluminar VMP00SM 0.691767\n', 'por por SPS00 1\n', 'dentro dentro RG 1\n', ', , Fc 1\n', 'nivela nivelar VMIP3S0 0.994868\n', 'automáticamente automáticamente RG 1\n', 'la el DA0FS0 0.972269\n', 'ropa ropa NCFS000 1\n', 'en en SPS00 1\n', 'el el DA0MS0 1\n', 'proceso proceso NCMS000 0.994505\n', 'de de SPS00 0.999984\n', 'centrifugado centrifugado NCMS000 0.308252\n', ', , Fc 1\n', 'y y CC 0.999962\n', 'una uno DI0FS0 0.951575\n', 'de de SPS00 0.999984\n', 'las el DA0FP0 0.970954\n', 'novedades novedad NCFP000 1\n', 'es ser VSIP3S0 1\n', 'el el DA0MS0 1\n', 'Vapor vapor NP00000 1\n', 'y y CC 0.999962\n', 'el el DA0MS0 1\n', 'Protex protex NP00000 1\n', 'entre entre SPS00 0.998082\n', 'otras otro DI0FP0 0.734962\n', 'muchas mucho DI0FP0 0.826705\n', 'ventajas ventaja NCFP000 1\n', '. . Fp 1\n', '\n', 'Si si CS 0.99954\n', 'estáis estar VAIP2P0 1\n', 'buscando buscar VMG0000 1\n', 'una uno DI0FS0 0.951575\n', 'lavadora lavadora NCFS000 0.414738\n', 'de de SPS00 0.999984\n', 'larga  ...

# %%
# Open the file for reading.
# the file is encoded with iso-8859-1
import codecs
with codecs.open('/Users/user/jupyter_notebooks/python_ETL/OpinionsTXT/AEG_Electrolux_60840_Lavamat__Opinion_1506705.html.txt', 'r', encoding='iso-8859-1') as infile:
    data = infile.read()

print(data)
# Out:
# Silencio y facilidad. Con estas dos palabras se puede definir este aparato.
# Además de la multitud de programas que posee para diferentes tejidos (8 programas de lavado, incluyendo seda, lavado a mano y ecológico), su display te informa del tiempo aproximado de cada ciclo de lavado.
#
#
# Hasta el momento no hemos tenido ningún sobresalto. La ropa de nuestro bebé sale impecable y sin encoger. Tiene diferentes revoluciones para el centrifugado, además de programas especiales para ropa sensible y planchado fácil.
# Tiene además una función especial de inicio diferido para que la lavadora termine el ciclo en tiempo cercano al que vayas a llegar a casa y poder tender la ropa.
#
#
# El silencio es uno de sus puntos fuertes, incluso cuando está en la fase de centrifugado.
# La única desventaja que por ahora hemos encontrado es la señal acústica que informa del fin del ciclo de lavado. Está constantemente lanzando un ";piii"; hasta que vas a ponerla en off.
#
#
# Estéticamente no desagrada a la vista y encaja bien si es necesario ponerla en un lugar visible de la cocina.
# Tiene una carga máxima de 6 kg. Su máxima velocidad de centrifugado es de 1.000 rpm y el consumo máximo es de 63 litros de agua.

# %%
#This functions convert a directory full of documents to a single .csv file
import glob, os
import sys
sys.stdout=open("/Users/user/jupyter_notebooks/python_ETL/new_corpus.csv","w")

directory_path = '/Users/user/jupyter_notebooks/python_ETL/OpinionsTXT/'
def retrive(directory_path):
    for filename in sorted(glob.glob(os.path.join(directory_path, '*.txt'))):
        with codecs.open(filename, 'r', encoding='iso-8859-1') as f:
            important_stuff = f.read().splitlines()
            oneline = [''.join(important_stuff)]
            print( filename.split('/')[-1] + '| ' +str(oneline).strip('[]"'))


print (retrive(directory_path))

# %%
import pandas as pd
df = pd.read_csv('/Users/user/jupyter_notebooks/python_ETL/new_corpus.csv', sep='|', names=['id', 'opinions'])
df.head(10)
# Out:
#                                                   id  \
# 0  AEG_Electrolux_60840_Lavamat__Opinion_1506705....
# 1  AEG_Electrolux_62610_Lavamat__Opinion_2000923....
# 2  AEG_Electrolux_L14800VI__Opinion_2005396.html.txt
# 3   AEG_Electrolux_L6227FL__Opinion_2140710.html.txt
# 4  AEG_Electrolux_L62280FL__Opinion_2151025.html.txt
# 5  AEG_Electrolux_L62642VI__Opinion_1995158.html.txt
# 6  AEG_Electrolux_L62642VI__Opinion_1995791.html.txt
# 7  AEG_Electrolux_L70470FL__Opinion_2085167.html.txt
# 8    AEG_Electrolux_L74650__Opinion_1856967.html.txt
# 9  AEG_Electrolux_L85275XFL__Opinion_2138100.html...
#
#                                             opinions
# 0   'Silencio y facilidad. Con estas dos palabras...
# 1   'Hola compis!No sabía como se ponía una lavad...
# 2   'Esta lavadora es de lo más práctica para aqu...
# 3   'Buenas tardes amigos y compañeros de ciao......
# 4   'Empecemos por una ventaja muy importante: la...
# 5   'Una vez demostrado que puede haber gente que...
# 6   'Monté mi nueva cocina hace unos 6 meses y es...
# 7   EL MODELOEl modelo  L70470FL de AEG-Electrolu...
# 8   'Buenas, os quiero comentaros sobre esta lava...
# 9   'Hoy voy a escribir sobre una lavadora que co...
